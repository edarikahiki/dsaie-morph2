# %% [markdown]
# # JamUNet model trained with the spatial dataset - training and validation
#
# This notebook was used for training and validating the model.

# %%
# move to root directory

# %cd ..
# Out:
# /workspace/dsaie-morph2

# %%
# reload modules to avoid restarting the notebook every time these are updated

# %load_ext autoreload
# %autoreload 2

# %%
# import modules 

import torch
import joblib
import copy

from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import StepLR

from model.train_eval import * 
from preprocessing.dataset_generation import create_full_dataset
from postprocessing.save_results import *
from postprocessing.plot_results import *

from urllib.request import urlretrieve

# enable interactive widgets in Jupyter Notebook
# %matplotlib inline
# %matplotlib widget

# %%
# set the device where operations are performed
# if only one GPU is present you might need to remove the index "0" 
# torch.device('cuda:0') --> torch.device('cuda') / torch.cuda.get_device_name(0) --> torch.cuda.get_device_name() 

if torch.cuda.is_available():
    device = torch.device('cuda:0')
    print("CUDA Device Count: ", torch.cuda.device_count())
    print("CUDA Device Name: ", torch.cuda.get_device_name(0))
else:
    device = 'cpu'
    
print(f'Using device: {device}')
# Out:
# CUDA Device Count:  1
# CUDA Device Name:  NVIDIA A100-SXM4-80GB
# Using device: cuda:0

# %%
# url = 'https://puprtes-my.sharepoint.com/:u:/r/personal/adriehakiki_pu_go_id/Documents/CE%20TU%20Delft/DSAIE/datasets/original.joblib?csf=1&web=1&e=gWeEPV'

# urlretrieve(url, "dataset.joblib")

# %%
# set common keys required for functions

train = 'training'
val = 'validation'
test = 'testing'

# %%
# import pickle


stored_dataset_path = r'data/satellite/loaded_datasets'
dataset_name = 'original'

dataset_loc = os.path.join(stored_dataset_path, f'{dataset_name}.joblib')


if os.path.exists(dataset_loc):
    train_set, val_set, test_set = joblib.load(dataset_loc)
else:
    dataset_path = r'data/satellite/dataset_month3' 

    dtype=torch.float32

    train_set = create_full_dataset(train, dir_folders=dataset_path, device=device, dtype=dtype)
    val_set = create_full_dataset(val, dir_folders=dataset_path, device=device, dtype=dtype)
    test_set = create_full_dataset(test, dir_folders=dataset_path, device=device, dtype=dtype)

    dataset = [train_set,val_set,test_set]
    os.makedirs(stored_dataset_path, exist_ok=True)
    joblib.dump(dataset, dataset_loc)

# %%
# # load all datasets

# # by default March images are used - if another month is used change the number (available months: 1-4)
# dataset_path = r'data\satellite\dataset_month3' 

# dtype=torch.float32

# train_set = create_full_dataset(train, dir_folders=dataset_path, device=device, dtype=dtype)
# val_set = create_full_dataset(val, dir_folders=dataset_path, device=device, dtype=dtype)
# test_set = create_full_dataset(test, dir_folders=dataset_path, device=device, dtype=dtype)

# %%
print(f'Training dataset samples: {len(train_set)},\n\
Validation dataset samples: {len(val_set)},\n\
Testing dataset samples: {len(test_set)}')
# Out:
# Training dataset samples: 546,
# Validation dataset samples: 20,
# Testing dataset samples: 20

# %%
# # import pickle


# stored_dataset_path = r'data\satellite\datasets'
# os.makedirs(stored_dataset_path, exist_ok=True)

# dataset_name = 'original'


# dataset_loc = os.path.join(stored_dataset_path, f'{dataset_name}.joblib')


# if os.path.exists(dataset_loc):
#     # dataset = [train_set,val_set,test_set]
#     print('read joblib')
# else:
#     print()
#     # joblib.dump(dataset, dataset_loc)

# %%
# aa, ab, ac = joblib.load(dataset_loc)

# %% [markdown]
# **<span style="color:red">Attention!</span>**
# \
# Uncomment the next cells if larger training, validation, and testing datasets are needed. These cells load all months datasets (January, February, March, and April) and then merge them into one dataset.
# \
# Keep in mind that due to memory constraints, it is likely that not all four datasets can be loaded.
# \
# Make sure to load the training, validation, and testing datasets in different cells to reduce memory issues.

# %%
# dataset_jan = r'data\satellite\dataset_month1'
# dataset_feb = r'data\satellite\dataset_month2'
# dataset_mar = r'data\satellite\dataset_month3'
# dataset_apr = r'data\satellite\dataset_month4'

# dtype=torch.float32

# %%
# inputs_train_jan, targets_train_jan = create_full_dataset(train, dir_folders=dataset_jan, device=device, dtype=dtype).tensors
# inputs_train_feb, targets_train_feb = create_full_dataset(train, dir_folders=dataset_feb, device=device, dtype=dtype).tensors
# inputs_train_mar, targets_train_mar = create_full_dataset(train, dir_folders=dataset_mar, device=device, dtype=dtype).tensors
# inputs_train_apr, targets_train_apr = create_full_dataset(train, dir_folders=dataset_apr, device=device, dtype=dtype).tensors

# inputs_train = torch.cat((inputs_train_jan, inputs_train_feb, inputs_train_mar, inputs_train_apr))
# targets_train = torch.cat((targets_train_jan, targets_train_feb, targets_train_mar, targets_train_apr))
# train_set = TensorDataset(inputs_train, targets_train)

# %%
# inputs_val_jan, targets_val_jan = create_full_dataset(val, dir_folders=dataset_jan, device=device, dtype=dtype).tensors
# inputs_val_feb, targets_val_feb = create_full_dataset(val, dir_folders=dataset_feb, device=device, dtype=dtype).tensors
# inputs_val_mar, targets_val_mar = create_full_dataset(val, dir_folders=dataset_mar, device=device, dtype=dtype).tensors
# inputs_val_apr, targets_val_apr = create_full_dataset(val, dir_folders=dataset_apr, device=device, dtype=dtype).tensors

# inputs_val = torch.cat((inputs_val_jan, inputs_val_feb, inputs_val_mar, inputs_val_apr))
# targets_val = torch.cat((targets_val_jan, targets_val_feb, targets_val_mar, targets_val_apr))
# val_set = TensorDataset(inputs_val, targets_val)

# %%
# inputs_test_jan, targets_test_jan = create_full_dataset(test, dir_folders=dataset_jan, device=device, dtype=dtype).tensors
# inputs_test_feb, targets_test_feb = create_full_dataset(test, dir_folders=dataset_feb, device=device, dtype=dtype).tensors
# inputs_test_mar, targets_test_mar = create_full_dataset(test, dir_folders=dataset_mar, device=device, dtype=dtype).tensors
# inputs_test_apr, targets_test_apr = create_full_dataset(test, dir_folders=dataset_apr, device=device, dtype=dtype).tensors

# inputs_test = torch.cat((inputs_test_jan, inputs_test_feb, inputs_test_mar, inputs_test_apr))
# targets_test = torch.cat((targets_test_jan, targets_test_feb, targets_test_mar, targets_test_apr))
# test_set = TensorDataset(inputs_test, targets_test)

# %% [markdown]
# **<span style="color:red">Attention!</span>**
# \
# It is not needed to scale and normalize the dataset as the pixel values are already $[0, 1]$.
# \
# If scaling and normalization are performed anyways, then **the model inputs have to be changed** as the normalized datasets are used.

# %%
# normalize inputs and targets using the training dataset

# scaler_x, scaler_y = scaler(train_set)

# normalized_train_set = normalize_dataset(train_set, scaler_x, scaler_y)
# normalized_val_set = normalize_dataset(val_set, scaler_x, scaler_y)
# normalized_test_set = normalize_dataset(test_set, scaler_x, scaler_y)

# %%
# save scalers to be loaded in seperate notebooks (i.e., for testing the model)
# should not change unless seed is changed or augmentation increased (randomsplit changes)

# joblib.dump(scaler_x, r'model\scalers\scaler_x.joblib')
# joblib.dump(scaler_y, r'model\scalers\scaler_y.joblib')

# %%
# load JamUNet architecture

from model.st_unet.st_unet import *
# from model.st_unet.st_unet_mod_ver2 import *
# from model.st_unet.st_unet_mod import *
from model.st_unet.st_unet_25D import *

n_channels = train_set[0][0].shape[0]
n_classes = 1
init_hid_dim = 32
kernel_size = 3
pooling = 'max'
temporal_kernel = train_set[0][0].shape[0]

model = UNet3D(n_channels=n_channels, n_classes=n_classes, init_hid_dim=init_hid_dim, 
               kernel_size=kernel_size, pooling=pooling, bilinear=False, drop_channels=False)

model25 = UNet25D(n_channels=1, n_classes=n_classes, init_hid_dim=init_hid_dim, 
               kernel_size=kernel_size, temporal_kernel=temporal_kernel,pooling=pooling, bilinear=False, drop_channels=False)

# model25 = UNet25D(n_channels=1, n_classes=n_classes, init_hid_dim=init_hid_dim, 
#                kernel_size=kernel_size, temporal_kernel=temporal_kernel,pooling=pooling, bilinear=False, drop_channels=False)

# model25bot = UNet25D_bottleneck(n_channels=1, n_classes=n_classes, init_hid_dim=init_hid_dim, 
#                kernel_size=kernel_size, temporal_kernel=temporal_kernel,pooling=pooling, bilinear=False, drop_channels=False)

# %%
# print model architecture
model=model25
model
# Out:
# UNet25D(
#   (inc): DoubleConv3D(
#     (conv3d): Sequential(
#       (0): Conv3d(1, 32, kernel_size=(4, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (down1): Down2D(
#     (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (down2): Down2D(
#     (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (down3): Down2D(
#     (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (down4): Down2D(
#     (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (up1): Up2D(
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (up2): Up2D(
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (up3): Up2D(
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (up4): Up2D(
#     (up): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv2D(
#       (double_conv): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (outc): OutConv2D(
#     (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (sigmoid): Sigmoid()
# )

# %%
# print total number of parameters and model size

num_parameters = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {num_parameters:}")
model_size_MB = num_parameters * 4 / (1024 ** 2)  # assuming float32 precision
print(f"Model size: {model_size_MB:.2f} MB")
# Out:
# Number of parameters: 7760385
# Model size: 29.60 MB

# %% [markdown]
# **<span style="color:red">Attention!</span>**
# \
# Since it is not needed to scale and normalize the dataset (see above), the input for the Data Loader are not the normalized datasets.
# \
# If normalization is performed, the normalized datasets become the inputs to the model.

# %%
# hyperparameters
learning_rate = 0.05
batch_size = 16
num_epochs = 100
water_threshold = 0.5
physics = False    # no physics-induced loss terms in the training loss if False
alpha_er = 1e-4    # needed only if physics=True
alpha_dep = 1e-4   # needed only if physics=True

# optimizer to train the model with backpropagation
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# scheduler for decreasing the learning rate 
# every tot epochs (step_size) with given factor (gamma)
step_size = 15     # set to None to remove the scheduler
gamma = 0.75       # set to None to remove the scheduler
if (step_size and gamma) is not None:
    scheduler = StepLR(optimizer, step_size = step_size, gamma = gamma)

# dataloaders to input data to the model in batches -- see note above if normalization is performed
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True) 
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
# initialize training, validation losses and metrics
train_losses, val_losses = [], []
accuracies, precisions, recalls, f1_scores, csi_scores = [], [], [], [], []

# set classification loss - possible options: 'BCE', 'BCE_Logits', and 'Focal'
loss_f = 'BCE' 
# set regression loss for physics-induced terms
# possible options: 'Huber', 'RMSE', and 'MAE'
loss_er_dep = 'Huber'

for epoch in range(1, num_epochs+1):
    
    # update learning rate
    if (step_size and gamma) is not None:
        scheduler.step() # update the learning rate
    
    # model training
    train_loss = training_unet(model, train_loader, optimizer, water_threshold=water_threshold, 
                               device=device, loss_f=loss_f, physics=physics, alpha_er=alpha_er, 
                               alpha_dep=alpha_dep, loss_er_dep=loss_er_dep)

    # model validation
    val_loss, val_accuracy, val_precision, val_recall, val_f1_score, val_csi_score = validation_unet(model, val_loader, 
                                                                                                     device=device, loss_f=loss_f, 
                                                                                                     water_threshold=water_threshold)

    if epoch == 1:
        best_loss = val_loss
        best_recall = val_recall
    
    # save model with min val loss
    if val_loss<=best_loss:
        best_model = copy.deepcopy(model)
        best_loss = val_loss
        best_epoch = epoch
        count = 0
    # save model with max recall
    if val_recall>=best_recall:
        best_model_recall = copy.deepcopy(model)
        best_recall = val_recall
        best_epoch = epoch
        count = 0

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    accuracies.append(val_accuracy)
    precisions.append(val_precision)
    recalls.append(val_recall)
    f1_scores.append(val_f1_score)
    csi_scores.append(val_csi_score)

    count += 1
    
    if epoch%1 == 0:
        print(f"Epoch: {epoch} | " +
              f"Training loss: {train_loss:.2e}, Validation loss: {val_loss:.2e}, Best validation loss: {best_loss:.2e} " + 
              f" | Metrics: Accuracy: {val_accuracy:.3f}, Precision: {val_precision:.3f}, Recall: {val_recall:.3f},\
 F1-score: {val_f1_score:.3f}, CSI-score: {val_csi_score:.3f}, Best recall: {best_recall:.3f}")
        if (step_size and gamma) is not None:
            print(f'Current learning rate: {scheduler.get_last_lr()[0]}')
# Out:
# Epoch: 1 | Training loss: 4.52e-01, Validation loss: 6.84e-01, Best validation loss: 6.84e-01  | Metrics: Accuracy: 0.860, Precision: 0.393, Recall: 0.645, F1-score: 0.488, CSI-score: 0.323, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 2 | Training loss: 1.94e-01, Validation loss: 1.76e-01, Best validation loss: 1.76e-01  | Metrics: Accuracy: 0.918, Precision: 0.705, Recall: 0.363, F1-score: 0.479, CSI-score: 0.315, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 3 | Training loss: 1.85e-01, Validation loss: 1.64e-01, Best validation loss: 1.64e-01  | Metrics: Accuracy: 0.924, Precision: 0.635, Recall: 0.638, F1-score: 0.637, CSI-score: 0.467, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 4 | Training loss: 1.79e-01, Validation loss: 1.61e-01, Best validation loss: 1.61e-01  | Metrics: Accuracy: 0.926, Precision: 0.665, Recall: 0.583, F1-score: 0.621, CSI-score: 0.450, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 5 | Training loss: 1.77e-01, Validation loss: 1.58e-01, Best validation loss: 1.58e-01  | Metrics: Accuracy: 0.927, Precision: 0.684, Recall: 0.552, F1-score: 0.611, CSI-score: 0.440, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 6 | Training loss: 1.75e-01, Validation loss: 1.57e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.928, Precision: 0.666, Recall: 0.610, F1-score: 0.637, CSI-score: 0.467, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 7 | Training loss: 1.74e-01, Validation loss: 1.58e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.927, Precision: 0.672, Recall: 0.590, F1-score: 0.628, CSI-score: 0.458, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 8 | Training loss: 1.75e-01, Validation loss: 1.57e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.928, Precision: 0.696, Recall: 0.540, F1-score: 0.608, CSI-score: 0.437, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 9 | Training loss: 1.73e-01, Validation loss: 1.59e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.927, Precision: 0.699, Recall: 0.525, F1-score: 0.600, CSI-score: 0.428, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 10 | Training loss: 1.74e-01, Validation loss: 1.57e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.928, Precision: 0.697, Recall: 0.540, F1-score: 0.608, CSI-score: 0.437, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 11 | Training loss: 1.73e-01, Validation loss: 1.59e-01, Best validation loss: 1.57e-01  | Metrics: Accuracy: 0.928, Precision: 0.695, Recall: 0.545, F1-score: 0.611, CSI-score: 0.440, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 12 | Training loss: 1.73e-01, Validation loss: 1.56e-01, Best validation loss: 1.56e-01  | Metrics: Accuracy: 0.928, Precision: 0.686, Recall: 0.559, F1-score: 0.616, CSI-score: 0.446, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 13 | Training loss: 1.75e-01, Validation loss: 1.61e-01, Best validation loss: 1.56e-01  | Metrics: Accuracy: 0.926, Precision: 0.734, Recall: 0.448, F1-score: 0.556, CSI-score: 0.386, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 14 | Training loss: 1.71e-01, Validation loss: 1.61e-01, Best validation loss: 1.56e-01  | Metrics: Accuracy: 0.926, Precision: 0.729, Recall: 0.459, F1-score: 0.563, CSI-score: 0.392, Best recall: 0.645
# Current learning rate: 0.05
# Epoch: 15 | Training loss: 1.71e-01, Validation loss: 1.55e-01, Best validation loss: 1.55e-01  | Metrics: Accuracy: 0.928, Precision: 0.698, Recall: 0.547, F1-score: 0.613, CSI-score: 0.442, Best recall: 0.645
# Current learning rate: 0.037500000000000006
# Epoch: 16 | Training loss: 1.71e-01, Validation loss: 1.54e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.928, Precision: 0.669, Recall: 0.614, F1-score: 0.640, CSI-score: 0.471, Best recall: 0.645
# Current learning rate: 0.037500000000000006
# Epoch: 17 | Training loss: 1.71e-01, Validation loss: 1.54e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.928, Precision: 0.679, Recall: 0.593, F1-score: 0.633, CSI-score: 0.463, Best recall: 0.645
# Current learning rate: 0.037500000000000006
# Epoch: 18 | Training loss: 1.73e-01, Validation loss: 1.55e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.928, Precision: 0.659, Recall: 0.644, F1-score: 0.651, CSI-score: 0.483, Best recall: 0.645
# Current learning rate: 0.037500000000000006
# Epoch: 19 | Training loss: 1.72e-01, Validation loss: 1.57e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.927, Precision: 0.647, Recall: 0.666, F1-score: 0.656, CSI-score: 0.488, Best recall: 0.666
# Current learning rate: 0.037500000000000006
# Epoch: 20 | Training loss: 1.73e-01, Validation loss: 1.58e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.927, Precision: 0.730, Recall: 0.473, F1-score: 0.574, CSI-score: 0.403, Best recall: 0.666
# Current learning rate: 0.037500000000000006
# Epoch: 21 | Training loss: 1.71e-01, Validation loss: 1.56e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.928, Precision: 0.725, Recall: 0.491, F1-score: 0.585, CSI-score: 0.414, Best recall: 0.666
# Current learning rate: 0.037500000000000006
# Epoch: 22 | Training loss: 1.70e-01, Validation loss: 1.58e-01, Best validation loss: 1.54e-01  | Metrics: Accuracy: 0.928, Precision: 0.650, Recall: 0.670, F1-score: 0.660, CSI-score: 0.492, Best recall: 0.670
# Current learning rate: 0.037500000000000006
# Epoch: 23 | Training loss: 1.70e-01, Validation loss: 1.53e-01, Best validation loss: 1.53e-01  | Metrics: Accuracy: 0.929, Precision: 0.703, Recall: 0.548, F1-score: 0.616, CSI-score: 0.446, Best recall: 0.670
# Current learning rate: 0.037500000000000006
# Epoch: 24 | Training loss: 1.71e-01, Validation loss: 1.59e-01, Best validation loss: 1.53e-01  | Metrics: Accuracy: 0.930, Precision: 0.679, Recall: 0.614, F1-score: 0.645, CSI-score: 0.476, Best recall: 0.670
# Current learning rate: 0.037500000000000006
# Epoch: 25 | Training loss: 1.70e-01, Validation loss: 1.57e-01, Best validation loss: 1.53e-01  | Metrics: Accuracy: 0.927, Precision: 0.636, Recall: 0.704, F1-score: 0.668, CSI-score: 0.502, Best recall: 0.704
# Current learning rate: 0.037500000000000006
# Epoch: 26 | Training loss: 1.70e-01, Validation loss: 1.53e-01, Best validation loss: 1.53e-01  | Metrics: Accuracy: 0.930, Precision: 0.704, Recall: 0.568, F1-score: 0.629, CSI-score: 0.459, Best recall: 0.704
# Current learning rate: 0.037500000000000006
# Epoch: 27 | Training loss: 1.70e-01, Validation loss: 1.52e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.930, Precision: 0.679, Recall: 0.619, F1-score: 0.648, CSI-score: 0.479, Best recall: 0.704
# Current learning rate: 0.037500000000000006
# Epoch: 28 | Training loss: 1.71e-01, Validation loss: 1.54e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.929, Precision: 0.671, Recall: 0.624, F1-score: 0.646, CSI-score: 0.478, Best recall: 0.704
# Current learning rate: 0.037500000000000006
# Epoch: 29 | Training loss: 1.69e-01, Validation loss: 1.53e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.929, Precision: 0.658, Recall: 0.663, F1-score: 0.660, CSI-score: 0.493, Best recall: 0.704
# Current learning rate: 0.037500000000000006
# Epoch: 30 | Training loss: 1.68e-01, Validation loss: 1.52e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.930, Precision: 0.684, Recall: 0.607, F1-score: 0.643, CSI-score: 0.474, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 31 | Training loss: 1.69e-01, Validation loss: 1.53e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.930, Precision: 0.707, Recall: 0.561, F1-score: 0.625, CSI-score: 0.455, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 32 | Training loss: 1.69e-01, Validation loss: 1.55e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.931, Precision: 0.679, Recall: 0.635, F1-score: 0.656, CSI-score: 0.488, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 33 | Training loss: 1.68e-01, Validation loss: 1.52e-01, Best validation loss: 1.52e-01  | Metrics: Accuracy: 0.930, Precision: 0.733, Recall: 0.515, F1-score: 0.605, CSI-score: 0.434, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 34 | Training loss: 1.68e-01, Validation loss: 1.51e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.931, Precision: 0.685, Recall: 0.619, F1-score: 0.651, CSI-score: 0.482, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 35 | Training loss: 1.68e-01, Validation loss: 1.51e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.930, Precision: 0.674, Recall: 0.638, F1-score: 0.655, CSI-score: 0.488, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 36 | Training loss: 1.69e-01, Validation loss: 1.53e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.931, Precision: 0.680, Recall: 0.630, F1-score: 0.654, CSI-score: 0.486, Best recall: 0.704
# Current learning rate: 0.028125000000000004
# Epoch: 37 | Training loss: 1.68e-01, Validation loss: 1.53e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.928, Precision: 0.638, Recall: 0.713, F1-score: 0.673, CSI-score: 0.508, Best recall: 0.713
# Current learning rate: 0.028125000000000004
# Epoch: 38 | Training loss: 1.69e-01, Validation loss: 1.52e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.929, Precision: 0.648, Recall: 0.697, F1-score: 0.672, CSI-score: 0.506, Best recall: 0.713
# Current learning rate: 0.028125000000000004
# Epoch: 39 | Training loss: 1.68e-01, Validation loss: 1.64e-01, Best validation loss: 1.51e-01  | Metrics: Accuracy: 0.926, Precision: 0.621, Recall: 0.740, F1-score: 0.675, CSI-score: 0.510, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 40 | Training loss: 1.69e-01, Validation loss: 1.50e-01, Best validation loss: 1.50e-01  | Metrics: Accuracy: 0.931, Precision: 0.715, Recall: 0.557, F1-score: 0.626, CSI-score: 0.456, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 41 | Training loss: 1.69e-01, Validation loss: 1.51e-01, Best validation loss: 1.50e-01  | Metrics: Accuracy: 0.931, Precision: 0.699, Recall: 0.584, F1-score: 0.637, CSI-score: 0.467, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 42 | Training loss: 1.67e-01, Validation loss: 1.48e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.691, Recall: 0.614, F1-score: 0.650, CSI-score: 0.482, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 43 | Training loss: 1.69e-01, Validation loss: 1.53e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.930, Precision: 0.713, Recall: 0.549, F1-score: 0.620, CSI-score: 0.450, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 44 | Training loss: 1.70e-01, Validation loss: 1.72e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.926, Precision: 0.629, Recall: 0.709, F1-score: 0.667, CSI-score: 0.500, Best recall: 0.740
# Current learning rate: 0.028125000000000004
# Epoch: 45 | Training loss: 1.67e-01, Validation loss: 1.49e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.719, Recall: 0.557, F1-score: 0.628, CSI-score: 0.458, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 46 | Training loss: 1.68e-01, Validation loss: 1.50e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.695, Recall: 0.608, F1-score: 0.649, CSI-score: 0.480, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 47 | Training loss: 1.68e-01, Validation loss: 1.52e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.930, Precision: 0.718, Recall: 0.541, F1-score: 0.617, CSI-score: 0.446, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 48 | Training loss: 1.67e-01, Validation loss: 1.48e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.932, Precision: 0.698, Recall: 0.603, F1-score: 0.647, CSI-score: 0.479, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 49 | Training loss: 1.67e-01, Validation loss: 1.51e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.680, Recall: 0.631, F1-score: 0.655, CSI-score: 0.487, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 50 | Training loss: 1.68e-01, Validation loss: 1.52e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.929, Precision: 0.648, Recall: 0.703, F1-score: 0.675, CSI-score: 0.509, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 51 | Training loss: 1.67e-01, Validation loss: 1.49e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.706, Recall: 0.577, F1-score: 0.635, CSI-score: 0.466, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 52 | Training loss: 1.66e-01, Validation loss: 1.50e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.676, Recall: 0.653, F1-score: 0.664, CSI-score: 0.498, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 53 | Training loss: 1.70e-01, Validation loss: 1.51e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.692, Recall: 0.606, F1-score: 0.646, CSI-score: 0.478, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 54 | Training loss: 1.69e-01, Validation loss: 1.55e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.929, Precision: 0.652, Recall: 0.691, F1-score: 0.671, CSI-score: 0.505, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 55 | Training loss: 1.68e-01, Validation loss: 1.50e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.675, Recall: 0.647, F1-score: 0.661, CSI-score: 0.493, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 56 | Training loss: 1.67e-01, Validation loss: 1.48e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.932, Precision: 0.691, Recall: 0.622, F1-score: 0.655, CSI-score: 0.487, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 57 | Training loss: 1.67e-01, Validation loss: 1.49e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.932, Precision: 0.702, Recall: 0.603, F1-score: 0.649, CSI-score: 0.481, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 58 | Training loss: 1.67e-01, Validation loss: 1.53e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.931, Precision: 0.660, Recall: 0.685, F1-score: 0.672, CSI-score: 0.506, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 59 | Training loss: 1.68e-01, Validation loss: 1.49e-01, Best validation loss: 1.48e-01  | Metrics: Accuracy: 0.932, Precision: 0.709, Recall: 0.590, F1-score: 0.644, CSI-score: 0.475, Best recall: 0.740
# Current learning rate: 0.02109375
# Epoch: 60 | Training loss: 1.66e-01, Validation loss: 1.47e-01, Best validation loss: 1.47e-01  | Metrics: Accuracy: 0.932, Precision: 0.699, Recall: 0.613, F1-score: 0.653, CSI-score: 0.485, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 61 | Training loss: 1.67e-01, Validation loss: 1.49e-01, Best validation loss: 1.47e-01  | Metrics: Accuracy: 0.932, Precision: 0.710, Recall: 0.589, F1-score: 0.644, CSI-score: 0.475, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 62 | Training loss: 1.66e-01, Validation loss: 1.48e-01, Best validation loss: 1.47e-01  | Metrics: Accuracy: 0.932, Precision: 0.705, Recall: 0.596, F1-score: 0.646, CSI-score: 0.477, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 63 | Training loss: 1.65e-01, Validation loss: 1.47e-01, Best validation loss: 1.47e-01  | Metrics: Accuracy: 0.932, Precision: 0.697, Recall: 0.620, F1-score: 0.656, CSI-score: 0.489, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 64 | Training loss: 1.67e-01, Validation loss: 1.46e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.933, Precision: 0.706, Recall: 0.602, F1-score: 0.650, CSI-score: 0.482, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 65 | Training loss: 1.65e-01, Validation loss: 1.48e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.932, Precision: 0.669, Recall: 0.682, F1-score: 0.676, CSI-score: 0.510, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 66 | Training loss: 1.65e-01, Validation loss: 1.51e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.931, Precision: 0.763, Recall: 0.485, F1-score: 0.593, CSI-score: 0.422, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 67 | Training loss: 1.65e-01, Validation loss: 1.47e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.932, Precision: 0.747, Recall: 0.516, F1-score: 0.610, CSI-score: 0.439, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 68 | Training loss: 1.66e-01, Validation loss: 1.52e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.931, Precision: 0.743, Recall: 0.511, F1-score: 0.605, CSI-score: 0.434, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 69 | Training loss: 1.67e-01, Validation loss: 1.47e-01, Best validation loss: 1.46e-01  | Metrics: Accuracy: 0.932, Precision: 0.680, Recall: 0.661, F1-score: 0.670, CSI-score: 0.504, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 70 | Training loss: 1.64e-01, Validation loss: 1.45e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.708, Recall: 0.610, F1-score: 0.656, CSI-score: 0.488, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 71 | Training loss: 1.64e-01, Validation loss: 1.47e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.932, Precision: 0.674, Recall: 0.680, F1-score: 0.677, CSI-score: 0.512, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 72 | Training loss: 1.64e-01, Validation loss: 1.47e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.694, Recall: 0.631, F1-score: 0.661, CSI-score: 0.494, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 73 | Training loss: 1.65e-01, Validation loss: 1.50e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.692, Recall: 0.639, F1-score: 0.664, CSI-score: 0.497, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 74 | Training loss: 1.63e-01, Validation loss: 1.45e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.695, Recall: 0.629, F1-score: 0.661, CSI-score: 0.493, Best recall: 0.740
# Current learning rate: 0.015820312500000003
# Epoch: 75 | Training loss: 1.65e-01, Validation loss: 1.47e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.932, Precision: 0.671, Recall: 0.689, F1-score: 0.680, CSI-score: 0.515, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 76 | Training loss: 1.63e-01, Validation loss: 1.45e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.676, Recall: 0.681, F1-score: 0.678, CSI-score: 0.513, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 77 | Training loss: 1.64e-01, Validation loss: 1.48e-01, Best validation loss: 1.45e-01  | Metrics: Accuracy: 0.933, Precision: 0.679, Recall: 0.678, F1-score: 0.679, CSI-score: 0.514, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 78 | Training loss: 1.65e-01, Validation loss: 1.44e-01, Best validation loss: 1.44e-01  | Metrics: Accuracy: 0.934, Precision: 0.713, Recall: 0.607, F1-score: 0.656, CSI-score: 0.488, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 79 | Training loss: 1.63e-01, Validation loss: 1.52e-01, Best validation loss: 1.44e-01  | Metrics: Accuracy: 0.932, Precision: 0.657, Recall: 0.719, F1-score: 0.686, CSI-score: 0.523, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 80 | Training loss: 1.63e-01, Validation loss: 1.47e-01, Best validation loss: 1.44e-01  | Metrics: Accuracy: 0.934, Precision: 0.713, Recall: 0.610, F1-score: 0.658, CSI-score: 0.490, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 81 | Training loss: 1.64e-01, Validation loss: 1.44e-01, Best validation loss: 1.44e-01  | Metrics: Accuracy: 0.933, Precision: 0.702, Recall: 0.624, F1-score: 0.661, CSI-score: 0.494, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 82 | Training loss: 1.64e-01, Validation loss: 1.43e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.934, Precision: 0.708, Recall: 0.624, F1-score: 0.663, CSI-score: 0.497, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 83 | Training loss: 1.63e-01, Validation loss: 1.46e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.933, Precision: 0.684, Recall: 0.657, F1-score: 0.670, CSI-score: 0.504, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 84 | Training loss: 1.63e-01, Validation loss: 1.44e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.934, Precision: 0.715, Recall: 0.612, F1-score: 0.659, CSI-score: 0.492, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 85 | Training loss: 1.64e-01, Validation loss: 1.45e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.933, Precision: 0.721, Recall: 0.583, F1-score: 0.645, CSI-score: 0.476, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 86 | Training loss: 1.63e-01, Validation loss: 1.46e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.933, Precision: 0.685, Recall: 0.665, F1-score: 0.675, CSI-score: 0.510, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 87 | Training loss: 1.64e-01, Validation loss: 1.45e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.933, Precision: 0.681, Recall: 0.679, F1-score: 0.680, CSI-score: 0.515, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 88 | Training loss: 1.62e-01, Validation loss: 1.45e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.934, Precision: 0.721, Recall: 0.596, F1-score: 0.653, CSI-score: 0.485, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 89 | Training loss: 1.63e-01, Validation loss: 1.49e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.932, Precision: 0.658, Recall: 0.727, F1-score: 0.691, CSI-score: 0.528, Best recall: 0.740
# Current learning rate: 0.011865234375000002
# Epoch: 90 | Training loss: 1.63e-01, Validation loss: 1.49e-01, Best validation loss: 1.43e-01  | Metrics: Accuracy: 0.930, Precision: 0.644, Recall: 0.742, F1-score: 0.689, CSI-score: 0.526, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 91 | Training loss: 1.62e-01, Validation loss: 1.42e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.935, Precision: 0.713, Recall: 0.621, F1-score: 0.664, CSI-score: 0.497, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 92 | Training loss: 1.62e-01, Validation loss: 1.45e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.715, Recall: 0.608, F1-score: 0.657, CSI-score: 0.490, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 93 | Training loss: 1.62e-01, Validation loss: 1.45e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.701, Recall: 0.631, F1-score: 0.664, CSI-score: 0.498, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 94 | Training loss: 1.62e-01, Validation loss: 1.44e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.701, Recall: 0.645, F1-score: 0.672, CSI-score: 0.506, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 95 | Training loss: 1.62e-01, Validation loss: 1.43e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.712, Recall: 0.618, F1-score: 0.662, CSI-score: 0.495, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 96 | Training loss: 1.62e-01, Validation loss: 1.44e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.676, Recall: 0.694, F1-score: 0.685, CSI-score: 0.521, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 97 | Training loss: 1.61e-01, Validation loss: 1.44e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.686, Recall: 0.672, F1-score: 0.679, CSI-score: 0.514, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 98 | Training loss: 1.62e-01, Validation loss: 1.43e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.935, Precision: 0.720, Recall: 0.607, F1-score: 0.658, CSI-score: 0.491, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 99 | Training loss: 1.61e-01, Validation loss: 1.44e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.683, Recall: 0.684, F1-score: 0.684, CSI-score: 0.520, Best recall: 0.742
# Current learning rate: 0.00889892578125
# Epoch: 100 | Training loss: 1.61e-01, Validation loss: 1.42e-01, Best validation loss: 1.42e-01  | Metrics: Accuracy: 0.934, Precision: 0.693, Recall: 0.665, F1-score: 0.678, CSI-score: 0.514, Best recall: 0.742
# Current learning rate: 0.00889892578125

# %%
metrics = [accuracies, precisions, recalls, f1_scores, csi_scores]

# %%
# store training and validation losses and metrics to be stored in a .csv file for later postprocessing
# always check the dataset month key
dir_output = r'model/losses_metrics/19_HidLayer32_25D/'

os.makedirs(dir_output,exist_ok=True)

save_losses_metrics(train_losses, val_losses, metrics, 'spatial', model, 3, init_hid_dim, 
                    kernel_size, pooling, learning_rate, step_size, gamma, batch_size, num_epochs, 
                    water_threshold, physics, alpha_er, alpha_dep, dir_output=dir_output)
# Out:
# model/losses_metrics/19_HidLayer32_25D/UNet25D_spatial_losses&metrics_month3_4dwns_32ihiddim_3ker_maxpool_0.05ilr_15step_0.75gamma_16batch_100epochs_0.5wthr.csv

# %% [markdown]
# **<span style="color:red">Attention!</span>**
# \
# Always remember to rename the <code>save_path</code> file before running the whole notebook to avoid overwrting it.

# %%
# save model with min validation loss
# always check the dataset month key

save_model_path(best_model, 'spatial', 'loss', 3, init_hid_dim, kernel_size, pooling, learning_rate, 
                step_size, gamma, batch_size, num_epochs, water_threshold,dir_output=dir_output)
# Out:
# model/losses_metrics/19_HidLayer32_25D/UNet25D_bloss_spatial_month3_4dwns_32ihiddim_3ker_maxpool_0.05ilr_15step_0.75gamma_16batch_100epochs_0.5wthr.pth

# %%
# save model with max recall
# always check the dataset month key

save_model_path(best_model_recall, 'spatial', 'recall', 3, init_hid_dim, kernel_size, pooling, learning_rate, 
                step_size, gamma, batch_size, num_epochs, water_threshold,dir_output=dir_output)
# Out:
# model/losses_metrics/19_HidLayer32_25D/UNet25D_brecall_spatial_month3_4dwns_32ihiddim_3ker_maxpool_0.05ilr_15step_0.75gamma_16batch_100epochs_0.5wthr.pth

# %%
# test the min loss model - average loss and metrics

model_loss = copy.deepcopy(best_model)
test_loss, test_accuracy, test_precision, test_recall, test_f1_score, test_csi_score = validation_unet(model_loss, test_loader, device=device, loss_f = loss_f)

print(f'Average metrics for test dataset using model with best validation loss:\n\n\
{loss_f} loss:          {test_loss:.3e}\n\
Accuracy:          {test_accuracy:.3f}\n\
Precision:         {test_precision:.3f}\n\
Recall:            {test_recall:.3f}\n\
F1 score:          {test_f1_score:.3f}\n\
CSI score:         {test_csi_score:.3f}')
# Out:
# Average metrics for test dataset using model with best validation loss:
#
# BCE loss:          1.397e-01
# Accuracy:          0.936
# Precision:         0.716
# Recall:            0.723
# F1 score:          0.719
# CSI score:         0.561

# %%
# test the max recall model - average loss and metrics

model_recall = copy.deepcopy(best_model_recall)
test_loss, test_accuracy, test_precision, test_recall, test_f1_score, test_csi_score = validation_unet(model_recall, test_loader, device=device, loss_f = loss_f)

print(f'Average metrics for test dataset using model with best validation recall:\n\n\
{loss_f} loss:          {test_loss:.3e}\n\
Accuracy:          {test_accuracy:.3f}\n\
Precision:         {test_precision:.3f}\n\
Recall:            {test_recall:.3f}\n\
F1 score:          {test_f1_score:.3f}\n\
CSI score:         {test_csi_score:.3f}')
# Out:
# Average metrics for test dataset using model with best validation recall:
#
# BCE loss:          1.457e-01
# Accuracy:          0.933
# Precision:         0.676
# Recall:            0.780
# F1 score:          0.724
# CSI score:         0.568

# %%
plot_losses_metrics(train_losses, val_losses, metrics, model_recall, loss_f=loss_f)
# Out:
# ATTENTION: the argument `save_name` is not specified: the plot is not saved.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
show_evolution(18, test_set, model_loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 show_evolution(18, test_set, model_loss)
#
# NameError: name 'show_evolution' is not defined

# %%
show_evolution(18, test_set, model_recall)

# %%
show_evolution(18, val_set, model_recall)

# %%
single_roc_curve(model_loss, test_set, sample=18, device=device);

# %%
single_roc_curve(model_recall, test_set, sample=18, device=device);

# %%
get_total_roc_curve(model_loss, test_set, device=device);

# %%
get_total_roc_curve(model_recall, test_set, device=device);

# %%
single_pr_curve(model_loss, test_set, sample=19, device=device)

# %%
show_evolution(18, test_set, model_loss)
