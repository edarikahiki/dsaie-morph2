# %%
# !ls
# Out:
# 'Meeting Notes'				  dataset_month1_30.zip
#  README.md				  model
#  Unet3D_train_val_spatial_dataset.ipynb   postprocessing
#  Untitled.ipynb				  preprocessing
#  braided_mod.yml			  report.md
#  data					  testpush.txt

# %%
import zipfile
from tqdm import tqdm

with zipfile.ZipFile("dataset_month1_30.zip") as z:
    for file in tqdm(z.namelist()):
        z.extract(file, "/workspace/data")
# Out:
# 100%|██████████| 1051/1051 [00:16<00:00, 63.02it/s]
